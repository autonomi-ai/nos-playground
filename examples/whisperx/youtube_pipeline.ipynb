# %%
import nos
from nos.client import Client
from nos.logging import logger

# Run server through nos serve
# nos.init(runtime="auto", logging_level="DEBUG")

# Init NOS server, wait for it to spin up then confirm its healthy.
client = Client()

logger.debug("Waiting for server to start...")
client.WaitForServer()

logger.debug("Confirming server is healthy...")
if not client.IsHealthy():
    raise RuntimeError("NOS server is not healthy")

# %%
from pathlib import Path
import tempfile

def trim_audio(audio_path: Path, duration_s: int = 600) -> Path:
    import ffmpeg
    with tempfile.NamedTemporaryFile(suffix=Path(audio_path).suffix, delete=False) as tmp:
        audio_trimmed = ffmpeg.input(str(audio_path)).audio.filter("atrim", duration=duration_s)
        audio_output = ffmpeg.output(audio_trimmed, tmp.name)
        ffmpeg.run(audio_output, overwrite_output=True)
        return Path(tmp.name)

def download_youtube_url_and_transcribe(url):
    from yt_dlp import YoutubeDL

    ydl_opts = {
        "format": "bestaudio/best",
        "postprocessors": [
            {
                "key": "FFmpegExtractAudio",
                "preferredcodec": "wav",
                "preferredquality": "192",
            }
        ],
    }

    with YoutubeDL(ydl_opts) as ydl:
        # set download location to current directory
        info_dict = ydl.extract_info(url, download=False)
        output_filename = ydl.prepare_filename(info_dict)
        audio_filename = output_filename.replace(".webm", ".wav")
        error_code = ydl.download([url]) 
        assert error_code == 0

    # run transcription
    whisperx = client.Module("m-bain/whisperx-large-v2")
    assert whisperx is not None
    assert whisperx.GetModelInfo() is not None

    with client.UploadFile(trim_audio(audio_filename)) as remote_path:
        response = whisperx.transcribe(path=remote_path, batch_size=96)
    
        return response
    # assert isinstance(response, dict)
    # assert "text" in response
    # return response["text"]

# %%
transcription = download_youtube_url_and_transcribe("https://www.youtube.com/watch?v=Tfrrubw7pcE")
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Tfrrubw7pcE
# [youtube] Tfrrubw7pcE: Downloading webpage
# [youtube] Tfrrubw7pcE: Downloading ios player API JSON
# [youtube] Tfrrubw7pcE: Downloading android player API JSON
# [youtube] Tfrrubw7pcE: Downloading m3u8 information
# [youtube] Extracting URL: https://www.youtube.com/watch?v=Tfrrubw7pcE
# [youtube] Tfrrubw7pcE: Downloading webpage
# [youtube] Tfrrubw7pcE: Downloading ios player API JSON
# [youtube] Tfrrubw7pcE: Downloading android player API JSON
# [youtube] Tfrrubw7pcE: Downloading m3u8 information
# [info] Tfrrubw7pcE: Downloading 1 format(s): 251
# [download] Destination: Principles for Success： “Embrace Reality and Deal With It” ｜ Episode 2 [Tfrrubw7pcE].webm
# [download] 100% of    4.31MiB in 00:00:01 at 3.60MiB/s
# [ExtractAudio] Destination: Principles for Success： “Embrace Reality and Deal With It” ｜ Episode 2 [Tfrrubw7pcE].wav
# Deleting original file Principles for Success： “Embrace Reality and Deal With It” ｜ Episode 2 [Tfrrubw7pcE].webm (pass -k to keep)
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Guessed Channel Layout for Input Stream #0.0 : stereo
# Input #0, wav, from 'Principles for Success： “Embrace Reality and Deal With It” ｜ Episode 2 [Tfrrubw7pcE].wav':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Duration: 00:04:13.50, bitrate: 1536 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, stereo, s16, 1536 kb/s
# Stream mapping:
#   Stream #0:0 (pcm_s16le) -> atrim
#   atrim -> Stream #0:0 (pcm_s16le)
# Press [q] to stop, [?] for help
# Output #0, wav, to '/tmp/tmpdykg4dde.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, stereo, s16, 1536 kb/s
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_s16le
# size=   47532kB time=00:04:13.48 bitrate=1536.1kbits/s speed=2.07e+03x
# video:0kB audio:47532kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.000160%

# %%
transcription
# Out:
# {'segments': [{'start': 0.229,
#    'end': 1.892,
#    'text': ' Principles for Success.',
#    'words': [{'word': 'Principles',
#      'start': 0.229,
#      'end': 0.75,
#      'score': 0.841,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'for',
#      'start': 0.79,
#      'end': 0.931,
#      'score': 0.839,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'Success.',
#      'start': 1.011,
#      'end': 1.492,
#      'score': 0.77,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 1.892,
#    'end': 7.262,
#    'text': 'An ultra-mini-series adventure in 30 minutes and in 8 episodes.',
#    'words': [{'word': 'An',
#      'start': 1.892,
#      'end': 1.973,
#      'score': 0.891,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'ultra-mini-series',
#      'start': 2.173,
#      'end': 3.415,
#      'score': 0.791,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'adventure',
#      'start': 3.455,
#      'end': 3.976,
#      'score': 0.874,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'in',
#      'start': 4.137,
#      'end': 4.217,
#      'score': 0.902,
#      'speaker': 'SPEAKER_00'},
#     {'word': '30'},
#     {'word': 'minutes',
#      'start': 4.758,
#      'end': 5.098,
#      'score': 0.879,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'and',
#      'start': 5.439,
#      'end': 5.539,
#      'score': 0.806,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'in',
#      'start': 5.599,
#      'end': 5.679,
#      'score': 0.96,
#      'speaker': 'SPEAKER_00'},
#     {'word': '8'},
#     {'word': 'episodes.',
#      'start': 5.96,
#      'end': 6.541,
#      'score': 0.833,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 7.262,
#    'end': 8.985,
#    'text': 'Episode 2.',
#    'words': [{'word': 'Episode',
#      'start': 7.262,
#      'end': 8.244,
#      'score': 0.835,
#      'speaker': 'SPEAKER_00'},
#     {'word': '2.'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 8.985,
#    'end': 11.47,
#    'text': 'Embrace reality and deal with it.',
#    'words': [{'word': 'Embrace',
#      'start': 8.985,
#      'end': 9.526,
#      'score': 0.871,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'reality',
#      'start': 9.607,
#      'end': 10.208,
#      'score': 0.791,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'and',
#      'start': 10.548,
#      'end': 10.668,
#      'score': 0.616,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'deal',
#      'start': 10.849,
#      'end': 11.149,
#      'score': 0.746,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'with',
#      'start': 11.209,
#      'end': 11.39,
#      'score': 0.874,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'it.',
#      'start': 11.43,
#      'end': 11.47,
#      'score': 0.994,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 12.768,
#    'end': 17.152,
#    'text': ' The path you take in life is your most important decision.',
#    'words': [{'word': 'The',
#      'start': 12.768,
#      'end': 12.888,
#      'score': 0.882,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'path',
#      'start': 12.968,
#      'end': 13.329,
#      'score': 0.856,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'you',
#      'start': 13.389,
#      'end': 13.589,
#      'score': 0.944,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'take',
#      'start': 13.629,
#      'end': 13.889,
#      'score': 0.731,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'in',
#      'start': 13.929,
#      'end': 14.009,
#      'score': 0.833,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'life',
#      'start': 14.109,
#      'end': 14.41,
#      'score': 0.715,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'is',
#      'start': 14.59,
#      'end': 14.67,
#      'score': 0.68,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'your',
#      'start': 14.71,
#      'end': 14.87,
#      'score': 0.911,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'most',
#      'start': 14.99,
#      'end': 15.25,
#      'score': 0.825,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'important',
#      'start': 15.33,
#      'end': 15.771,
#      'score': 0.908,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'decision.',
#      'start': 15.811,
#      'end': 16.211,
#      'score': 0.898,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 17.152,
#    'end': 24.638,
#    'text': 'In my case, I wanted my life to be great, and I feared boredom and mediocrity more than I feared failure.',
#    'words': [{'word': 'In',
#      'start': 17.152,
#      'end': 17.232,
#      'score': 0.844,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'my',
#      'start': 17.312,
#      'end': 17.492,
#      'score': 0.788,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'case,',
#      'start': 17.532,
#      'end': 17.772,
#      'score': 0.777,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'I',
#      'start': 17.953,
#      'end': 18.013,
#      'score': 0.665,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'wanted',
#      'start': 18.053,
#      'end': 18.333,
#      'score': 0.918,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'my',
#      'start': 18.393,
#      'end': 18.533,
#      'score': 0.808,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'life',
#      'start': 18.613,
#      'end': 18.833,
#      'score': 0.834,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'to',
#      'start': 18.893,
#      'end': 18.994,
#      'score': 0.731,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'be',
#      'start': 19.034,
#      'end': 19.174,
#      'score': 0.893,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'great,',
#      'start': 19.314,
#      'end': 19.754,
#      'score': 0.832,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'and',
#      'start': 19.994,
#      'end': 20.094,
#      'score': 0.931,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'I',
#      'start': 20.175,
#      'end': 20.235,
#      'score': 0.66,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'feared',
#      'start': 20.395,
#      'end': 20.715,
#      'score': 0.895,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'boredom',
#      'start': 20.815,
#      'end': 21.235,
#      'score': 0.855,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'and',
#      'start': 21.416,
#      'end': 21.516,
#      'score': 0.831,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'mediocrity',
#      'start': 21.576,
#      'end': 22.316,
#      'score': 0.961,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'more',
#      'start': 22.376,
#      'end': 22.557,
#      'score': 0.944,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'than',
#      'start': 22.597,
#      'end': 22.737,
#      'score': 0.91,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'I',
#      'start': 22.817,
#      'end': 22.877,
#      'score': 0.719,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'feared',
#      'start': 22.977,
#      'end': 23.257,
#      'score': 0.818,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'failure.',
#      'start': 23.357,
#      'end': 23.778,
#      'score': 0.894,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 24.638,
#    'end': 33.807,
#    'text': "Since I didn't start out with money, and I didn't need much more than a bed to sleep in and food to eat, I could skew my decisions to pursue my adventures.",
#    'words': [{'word': 'Since',
#      'start': 24.638,
#      'end': 24.859,
#      'score': 0.973,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'I',
#      'start': 24.939,
#      'end': 24.999,
#      'score': 0.666,
#      'speaker': 'SPEAKER_00'},
#     {'word': "didn't",
#      'start': 25.019,
#      'end': 25.239,
#      'score': 0.849,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'start',
#      'start': 25.299,
#      'end': 25.559,
#      'score': 0.852,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'out',
#      'start': 25.659,
#      'end': 25.759,
#      'score': 0.83,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'with',
#      'start': 25.82,
#      'end': 25.96,
#      'score': 0.847,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'money,',
#      'start': 26.04,
#      'end': 26.3,
#      'score': 0.594,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'and',
#      'start': 26.58,
#      'end': 26.7,
#      'score': 0.783,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'I',
#      'start': 26.74,
#      'end': 26.78,
#      'score': 0.991,
#      'speaker': 'SPEAKER_00'},
#     {'word': "didn't",
#      'start': 26.82,
#      'end': 27.081,
#      'score': 0.725,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'need',
#      'start': 27.141,
#      'end': 27.321,
#      'score': 0.93,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'much',
#      'start': 27.381,
#      'end': 27.601,
#      'score': 0.702,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'more',
#      'start': 27.681,
#      'end': 27.821,
#      'score': 0.882,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'than',
#      'start': 27.881,
#      'end': 28.021,
#      'score': 0.909,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'a',
#      'start': 28.061,
#      'end': 28.102,
#      'score': 0.499,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'bed',
#      'start': 28.162,
#      'end': 28.402,
#      'score': 0.8,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'to',
#      'start': 28.442,
#      'end': 28.542,
#      'score': 0.882,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'sleep',
#      'start': 28.622,
#      'end': 28.882,
#      'score': 0.897,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'in',
#      'start': 28.982,
#      'end': 29.062,
#      'score': 0.883,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'and',
#      'start': 29.122,
#      'end': 29.202,
#      'score': 0.758,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'food',
#      'start': 29.263,
#      'end': 29.523,
#      'score': 0.789,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'to',
#      'start': 29.563,
#      'end': 29.663,
#      'score': 0.942,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'eat,',
#      'start': 29.783,
#      'end': 29.943,
#      'score': 0.72,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'I',
#      'start': 30.283,
#      'end': 30.323,
#      'score': 0.998,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'could',
#      'start': 30.384,
#      'end': 30.564,
#      'score': 0.759,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'skew',
#      'start': 30.624,
#      'end': 30.964,
#      'score': 0.882,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'my',
#      'start': 31.024,
#      'end': 31.144,
#      'score': 0.844,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'decisions',
#      'start': 31.204,
#      'end': 31.705,
#      'score': 0.797,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'to',
#      'start': 31.785,
#      'end': 31.905,
#      'score': 0.852,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'pursue',
#      'start': 31.985,
#      'end': 32.425,
#      'score': 0.893,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'my',
#      'start': 32.485,
#      'end': 32.625,
#      'score': 0.996,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'adventures.',
#      'start': 32.686,
#      'end': 33.226,
#      'score': 0.851,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 33.807,
#    'end': 37.57,
#    'text': 'So ever since I was a kid, I ran after the things I wanted,',
#    'words': [{'word': 'So',
#      'start': 33.807,
#      'end': 33.947,
#      'score': 0.98,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'ever',
#      'start': 34.107,
#      'end': 34.287,
#      'score': 0.72,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'since',
#      'start': 34.347,
#      'end': 34.587,
#      'score': 0.684,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'I',
#      'start': 34.667,
#      'end': 34.727,
#      'score': 0.754,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'was',
#      'start': 34.787,
#      'end': 34.948,
#      'score': 0.781,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'a',
#      'start': 35.008,
#      'end': 35.048,
#      'score': 0.531,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'kid,',
#      'start': 35.128,
#      'end': 35.408,
#      'score': 0.836,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'I',
#      'start': 35.628,
#      'end': 35.688,
#      'score': 0.668,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'ran',
#      'start': 35.788,
#      'end': 36.068,
#      'score': 0.831,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'after',
#      'start': 36.209,
#      'end': 36.429,
#      'score': 0.902,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'the',
#      'start': 36.489,
#      'end': 36.569,
#      'score': 0.833,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'things',
#      'start': 36.629,
#      'end': 36.909,
#      'score': 0.873,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'I',
#      'start': 37.029,
#      'end': 37.109,
#      'score': 0.685,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'wanted,',
#      'start': 37.209,
#      'end': 37.57,
#      'score': 0.947,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 38.15,
#    'end': 48.975,
#    'text': ' crashed, got up and ran again, and crashed again, and each time I crashed, I learned something, got better, and crashed less.',
#    'words': [{'word': 'crashed,',
#      'start': 38.15,
#      'end': 38.79,
#      'score': 0.716,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'got',
#      'start': 39.271,
#      'end': 39.531,
#      'score': 0.846,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'up',
#      'start': 39.631,
#      'end': 39.731,
#      'score': 0.992,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'and',
#      'start': 39.851,
#      'end': 39.951,
#      'score': 0.671,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'ran',
#      'start': 40.031,
#      'end': 40.311,
#      'score': 0.933,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'again,',
#      'start': 40.391,
#      'end': 40.671,
#      'score': 0.781,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'and',
#      'start': 41.352,
#      'end': 41.472,
#      'score': 0.992,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'crashed',
#      'start': 41.532,
#      'end': 41.932,
#      'score': 0.742,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'again,',
#      'start': 41.992,
#      'end': 42.292,
#      'score': 0.839,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'and',
#      'start': 42.912,
#      'end': 43.032,
#      'score': 0.706,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'each',
#      'start': 43.153,
#      'end': 43.353,
#      'score': 0.725,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'time',
#      'start': 43.413,
#      'end': 43.673,
#      'score': 0.866,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'I',
#      'start': 43.753,
#      'end': 43.813,
#      'score': 0.677,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'crashed,',
#      'start': 43.913,
#      'end': 44.393,
#      'score': 0.738,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'I',
#      'start': 44.613,
#      'end': 44.693,
#      'score': 0.506,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'learned',
#      'start': 44.753,
#      'end': 45.053,
#      'score': 0.835,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'something,',
#      'start': 45.154,
#      'end': 45.654,
#      'score': 0.862,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'got',
#      'start': 46.054,
#      'end': 46.274,
#      'score': 0.935,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'better,',
#      'start': 46.374,
#      'end': 46.714,
#      'score': 0.724,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'and',
#      'start': 47.214,
#      'end': 47.315,
#      'score': 0.677,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'crashed',
#      'start': 47.375,
#      'end': 47.815,
#      'score': 0.791,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'less.',
#      'start': 47.875,
#      'end': 48.235,
#      'score': 0.866,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 48.975,
#    'end': 55.819,
#    'text': 'By doing that over and over again, I learned to love this process, even the crashing part of it.',
#    'words': [{'word': 'By',
#      'start': 48.975,
#      'end': 49.155,
#      'score': 0.857,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'doing',
#      'start': 49.215,
#      'end': 49.516,
#      'score': 0.782,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'that',
#      'start': 49.556,
#      'end': 49.736,
#      'score': 0.83,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'over',
#      'start': 49.956,
#      'end': 50.156,
#      'score': 0.844,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'and',
#      'start': 50.216,
#      'end': 50.296,
#      'score': 0.883,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'over',
#      'start': 50.396,
#      'end': 50.596,
#      'score': 0.789,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'again,',
#      'start': 50.676,
#      'end': 50.956,
#      'score': 0.883,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'I',
#      'start': 51.356,
#      'end': 51.437,
#      'score': 0.747,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'learned',
#      'start': 51.517,
#      'end': 51.797,
#      'score': 0.867,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'to',
#      'start': 51.837,
#      'end': 51.937,
#      'score': 0.766,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'love',
#      'start': 52.057,
#      'end': 52.317,
#      'score': 0.824,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'this',
#      'start': 52.377,
#      'end': 52.557,
#      'score': 0.708,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'process,',
#      'start': 52.637,
#      'end': 53.177,
#      'score': 0.792,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'even',
#      'start': 53.598,
#      'end': 53.818,
#      'score': 0.819,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'the',
#      'start': 53.858,
#      'end': 53.958,
#      'score': 0.669,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'crashing',
#      'start': 54.018,
#      'end': 54.478,
#      'score': 0.764,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'part',
#      'start': 54.518,
#      'end': 54.718,
#      'score': 0.876,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'of',
#      'start': 54.758,
#      'end': 54.818,
#      'score': 0.988,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'it.',
#      'start': 54.898,
#      'end': 54.998,
#      'score': 0.982,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 55.819,
#    'end': 58.24,
#    'text': 'Through it, I encountered reality.',
#    'words': [{'word': 'Through',
#      'start': 55.819,
#      'end': 56.179,
#      'score': 0.653,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'it,',
#      'start': 56.239,
#      'end': 56.319,
#      'score': 0.652,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'I',
#      'start': 56.779,
#      'end': 56.839,
#      'score': 0.893,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'encountered',
#      'start': 56.939,
#      'end': 57.559,
#      'score': 0.813,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'reality.',
#      'start': 57.639,
#      'end': 58.24,
#      'score': 0.894,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 58.965,
#    'end': 71.553,
#    'text': ' and I learned how to deal with it, which inspired another one of my most fundamental principles, which is that truth is the essential foundation for producing good outcomes.',
#    'words': [{'word': 'and',
#      'start': 58.965,
#      'end': 59.065,
#      'score': 0.797,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'I',
#      'start': 59.145,
#      'end': 59.225,
#      'score': 0.547,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'learned',
#      'start': 59.285,
#      'end': 59.605,
#      'score': 0.698,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'how',
#      'start': 59.666,
#      'end': 59.826,
#      'score': 0.827,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'to',
#      'start': 59.846,
#      'end': 59.926,
#      'score': 0.736,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'deal',
#      'start': 60.026,
#      'end': 60.286,
#      'score': 0.73,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'with',
#      'start': 60.326,
#      'end': 60.486,
#      'score': 0.72,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'it,',
#      'start': 60.566,
#      'end': 60.626,
#      'score': 0.754,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'which',
#      'start': 61.166,
#      'end': 61.367,
#      'score': 0.768,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'inspired',
#      'start': 61.447,
#      'end': 62.047,
#      'score': 0.897,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'another',
#      'start': 62.247,
#      'end': 62.707,
#      'score': 0.856,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'one',
#      'start': 62.868,
#      'end': 62.988,
#      'score': 0.918,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'of',
#      'start': 63.028,
#      'end': 63.088,
#      'score': 0.75,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'my',
#      'start': 63.128,
#      'end': 63.268,
#      'score': 0.83,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'most',
#      'start': 63.328,
#      'end': 63.548,
#      'score': 0.614,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'fundamental',
#      'start': 63.608,
#      'end': 64.268,
#      'score': 0.813,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'principles,',
#      'start': 64.309,
#      'end': 64.909,
#      'score': 0.769,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'which',
#      'start': 65.129,
#      'end': 65.309,
#      'score': 0.82,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'is',
#      'start': 65.429,
#      'end': 65.509,
#      'score': 0.729,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'that',
#      'start': 65.609,
#      'end': 65.829,
#      'score': 0.819,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'truth',
#      'start': 66.25,
#      'end': 66.69,
#      'score': 0.725,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'is',
#      'start': 67.11,
#      'end': 67.19,
#      'score': 0.73,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'the',
#      'start': 67.23,
#      'end': 67.33,
#      'score': 0.739,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'essential',
#      'start': 67.391,
#      'end': 67.951,
#      'score': 0.827,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'foundation',
#      'start': 68.051,
#      'end': 68.791,
#      'score': 0.8,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'for',
#      'start': 68.891,
#      'end': 69.052,
#      'score': 0.856,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'producing',
#      'start': 69.132,
#      'end': 69.832,
#      'score': 0.777,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'good',
#      'start': 69.912,
#      'end': 70.172,
#      'score': 0.734,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'outcomes.',
#      'start': 70.372,
#      'end': 70.853,
#      'score': 0.762,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 71.553,
#    'end': 75.316,
#    'text': "By truth, I don't mean anything more than the way the world works.",
#    'words': [{'word': 'By',
#      'start': 71.553,
#      'end': 71.693,
#      'score': 0.897,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'truth,',
#      'start': 71.793,
#      'end': 72.114,
#      'score': 0.823,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'I',
#      'start': 72.334,
#      'end': 72.354,
#      'score': 0.997,
#      'speaker': 'SPEAKER_00'},
#     {'word': "don't",
#      'start': 72.394,
#      'end': 72.574,
#      'score': 0.717,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'mean',
#      'start': 72.614,
#      'end': 72.814,
#      'score': 0.68,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'anything',
#      'start': 72.894,
#      'end': 73.274,
#      'score': 0.826,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'more',
#      'start': 73.354,
#      'end': 73.675,
#      'score': 0.696,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'than',
#      'start': 73.755,
#      'end': 73.955,
#      'score': 0.847,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'the',
#      'start': 73.975,
#      'end': 74.295,
#      'score': 0.609,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'way',
#      'start': 74.355,
#      'end': 74.535,
#      'score': 0.829,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'the',
#      'start': 74.575,
#      'end': 74.675,
#      'score': 0.874,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'world',
#      'start': 74.715,
#      'end': 74.975,
#      'score': 0.831,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'works.',
#      'start': 75.015,
#      'end': 75.316,
#      'score': 0.898,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 76.096,
#    'end': 80.32,
#    'text': ' I believe that we were given the laws of reality by nature.',
#    'words': [{'word': 'I',
#      'start': 76.096,
#      'end': 76.156,
#      'score': 0.667,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'believe',
#      'start': 76.196,
#      'end': 76.597,
#      'score': 0.774,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'that',
#      'start': 76.637,
#      'end': 76.757,
#      'score': 0.861,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'we',
#      'start': 76.817,
#      'end': 76.917,
#      'score': 0.988,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'were',
#      'start': 76.957,
#      'end': 77.117,
#      'score': 0.897,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'given',
#      'start': 77.177,
#      'end': 77.497,
#      'score': 0.757,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'the',
#      'start': 77.557,
#      'end': 77.638,
#      'score': 0.832,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'laws',
#      'start': 77.738,
#      'end': 78.138,
#      'score': 0.826,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'of',
#      'start': 78.218,
#      'end': 78.278,
#      'score': 0.75,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'reality',
#      'start': 78.378,
#      'end': 79.079,
#      'score': 0.787,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'by',
#      'start': 79.219,
#      'end': 79.419,
#      'score': 0.832,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'nature.',
#      'start': 79.539,
#      'end': 79.94,
#      'score': 0.799,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 80.32,
#    'end': 86.986,
#    'text': "Humans didn't create them, but we can use them to foster our own evolution and achieve our goals.",
#    'words': [{'word': 'Humans',
#      'start': 80.32,
#      'end': 80.74,
#      'score': 0.815,
#      'speaker': 'SPEAKER_00'},
#     {'word': "didn't",
#      'start': 80.78,
#      'end': 81.041,
#      'score': 0.803,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'create',
#      'start': 81.081,
#      'end': 81.421,
#      'score': 0.843,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'them,',
#      'start': 81.461,
#      'end': 81.601,
#      'score': 0.994,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'but',
#      'start': 81.981,
#      'end': 82.121,
#      'score': 0.99,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'we',
#      'start': 82.182,
#      'end': 82.302,
#      'score': 0.876,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'can',
#      'start': 82.362,
#      'end': 82.542,
#      'score': 0.991,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'use',
#      'start': 82.842,
#      'end': 83.042,
#      'score': 0.686,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'them',
#      'start': 83.102,
#      'end': 83.242,
#      'score': 0.991,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'to',
#      'start': 83.303,
#      'end': 83.423,
#      'score': 0.943,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'foster',
#      'start': 83.523,
#      'end': 84.003,
#      'score': 0.847,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'our',
#      'start': 84.083,
#      'end': 84.203,
#      'score': 0.78,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'own',
#      'start': 84.283,
#      'end': 84.404,
#      'score': 0.757,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'evolution',
#      'start': 84.464,
#      'end': 85.044,
#      'score': 0.873,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'and',
#      'start': 85.124,
#      'end': 85.224,
#      'score': 0.919,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'achieve',
#      'start': 85.284,
#      'end': 85.665,
#      'score': 0.766,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'our',
#      'start': 85.745,
#      'end': 85.845,
#      'score': 0.916,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'goals.',
#      'start': 85.885,
#      'end': 86.265,
#      'score': 0.832,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 86.986,
#    'end': 102.8,
#    'text': 'Realizing that made me a hyper-realist, by which I mean I became someone who has discovered the great rewards of deeply understanding, accepting, and working with reality as it is, and not as I wish it would be.',
#    'words': [{'word': 'Realizing',
#      'start': 86.986,
#      'end': 87.626,
#      'score': 0.812,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'that',
#      'start': 87.686,
#      'end': 87.867,
#      'score': 0.874,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'made',
#      'start': 88.007,
#      'end': 88.227,
#      'score': 0.859,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'me',
#      'start': 88.267,
#      'end': 88.387,
#      'score': 0.829,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'a',
#      'start': 88.447,
#      'end': 88.487,
#      'score': 0.499,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'hyper-realist,',
#      'start': 88.607,
#      'end': 89.708,
#      'score': 0.868,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'by',
#      'start': 90.309,
#      'end': 90.469,
#      'score': 0.83,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'which',
#      'start': 90.529,
#      'end': 90.709,
#      'score': 0.759,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'I',
#      'start': 90.809,
#      'end': 90.869,
#      'score': 0.895,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'mean',
#      'start': 90.929,
#      'end': 91.129,
#      'score': 0.732,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'I',
#      'start': 91.39,
#      'end': 91.45,
#      'score': 0.667,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'became',
#      'start': 91.55,
#      'end': 92.15,
#      'score': 0.908,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'someone',
#      'start': 92.29,
#      'end': 92.731,
#      'score': 0.794,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'who',
#      'start': 92.771,
#      'end': 92.891,
#      'score': 0.723,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'has',
#      'start': 92.931,
#      'end': 93.051,
#      'score': 0.958,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'discovered',
#      'start': 93.111,
#      'end': 93.632,
#      'score': 0.854,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'the',
#      'start': 93.672,
#      'end': 93.792,
#      'score': 0.756,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'great',
#      'start': 93.872,
#      'end': 94.192,
#      'score': 0.798,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'rewards',
#      'start': 94.252,
#      'end': 94.793,
#      'score': 0.881,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'of',
#      'start': 94.853,
#      'end': 94.913,
#      'score': 0.384,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'deeply',
#      'start': 94.993,
#      'end': 95.433,
#      'score': 0.892,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'understanding,',
#      'start': 95.513,
#      'end': 96.314,
#      'score': 0.889,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'accepting,',
#      'start': 96.654,
#      'end': 97.275,
#      'score': 0.799,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'and',
#      'start': 97.715,
#      'end': 97.775,
#      'score': 0.999,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'working',
#      'start': 97.875,
#      'end': 98.296,
#      'score': 0.854,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'with',
#      'start': 98.396,
#      'end': 98.656,
#      'score': 0.702,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'reality',
#      'start': 98.776,
#      'end': 99.377,
#      'score': 0.78,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'as',
#      'start': 99.697,
#      'end': 99.837,
#      'score': 0.797,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'it',
#      'start': 99.917,
#      'end': 99.977,
#      'score': 0.998,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'is,',
#      'start': 100.157,
#      'end': 100.298,
#      'score': 0.83,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'and',
#      'start': 100.878,
#      'end': 100.998,
#      'score': 0.502,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'not',
#      'start': 101.118,
#      'end': 101.399,
#      'score': 0.873,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'as',
#      'start': 101.619,
#      'end': 101.719,
#      'score': 0.838,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'I',
#      'start': 101.819,
#      'end': 101.859,
#      'score': 1.0,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'wish',
#      'start': 101.959,
#      'end': 102.199,
#      'score': 0.924,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'it',
#      'start': 102.259,
#      'end': 102.319,
#      'score': 0.887,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'would',
#      'start': 102.399,
#      'end': 102.58,
#      'score': 0.803,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'be.',
#      'start': 102.66,
#      'end': 102.8,
#      'score': 1.0,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 104.178,
#    'end': 110.804,
#    'text': " When I say I'm a hyper-realist, people sometimes think I'm saying that dreams can't come true.",
#    'words': [{'word': 'When',
#      'start': 104.178,
#      'end': 104.338,
#      'score': 0.458,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'I',
#      'start': 104.418,
#      'end': 104.498,
#      'score': 0.749,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'say',
#      'start': 104.578,
#      'end': 104.779,
#      'score': 0.858,
#      'speaker': 'SPEAKER_00'},
#     {'word': "I'm",
#      'start': 104.839,
#      'end': 105.019,
#      'score': 0.639,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'a',
#      'start': 105.079,
#      'end': 105.119,
#      'score': 0.503,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'hyper-realist,',
#      'start': 105.319,
#      'end': 106.42,
#      'score': 0.841,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'people',
#      'start': 106.82,
#      'end': 107.141,
#      'score': 0.74,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'sometimes',
#      'start': 107.201,
#      'end': 107.721,
#      'score': 0.834,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'think',
#      'start': 107.801,
#      'end': 108.002,
#      'score': 0.821,
#      'speaker': 'SPEAKER_00'},
#     {'word': "I'm",
#      'start': 108.062,
#      'end': 108.202,
#      'score': 0.707,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'saying',
#      'start': 108.262,
#      'end': 108.602,
#      'score': 0.75,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'that',
#      'start': 108.702,
#      'end': 108.882,
#      'score': 0.874,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'dreams',
#      'start': 108.962,
#      'end': 109.323,
#      'score': 0.825,
#      'speaker': 'SPEAKER_00'},
#     {'word': "can't",
#      'start': 109.403,
#      'end': 109.623,
#      'score': 0.851,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'come',
#      'start': 109.683,
#      'end': 109.863,
#      'score': 0.84,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'true.',
#      'start': 109.923,
#      'end': 110.184,
#      'score': 0.796,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 110.804,
#    'end': 113.206,
#    'text': "That's absolutely not true.",
#    'words': [{'word': "That's",
#      'start': 110.804,
#      'end': 111.084,
#      'score': 0.924,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'absolutely',
#      'start': 111.285,
#      'end': 111.905,
#      'score': 0.757,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'not',
#      'start': 111.965,
#      'end': 112.145,
#      'score': 0.829,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'true.',
#      'start': 112.246,
#      'end': 112.566,
#      'score': 0.776,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 113.206,
#    'end': 117.11,
#    'text': 'Without pursuing dreams, life is mundane.',
#    'words': [{'word': 'Without',
#      'start': 113.206,
#      'end': 113.587,
#      'score': 0.8,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'pursuing',
#      'start': 113.667,
#      'end': 114.267,
#      'score': 0.795,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'dreams,',
#      'start': 114.368,
#      'end': 114.848,
#      'score': 0.763,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'life',
#      'start': 115.128,
#      'end': 115.449,
#      'score': 0.736,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'is',
#      'start': 115.529,
#      'end': 115.629,
#      'score': 0.715,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'mundane.',
#      'start': 115.709,
#      'end': 116.309,
#      'score': 0.898,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 117.11,
#    'end': 123.376,
#    'text': "What I mean is that, to me, hyper-realism is the best way to choose one's dreams and then achieve them.",
#    'words': [{'word': 'What',
#      'start': 117.11,
#      'end': 117.31,
#      'score': 0.587,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'I',
#      'start': 117.37,
#      'end': 117.45,
#      'score': 0.726,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'mean',
#      'start': 117.51,
#      'end': 117.751,
#      'score': 0.765,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'is',
#      'start': 117.891,
#      'end': 118.011,
#      'score': 0.665,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'that,',
#      'start': 118.071,
#      'end': 118.271,
#      'score': 0.904,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'to',
#      'start': 118.351,
#      'end': 118.471,
#      'score': 0.978,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'me,',
#      'start': 118.571,
#      'end': 118.852,
#      'score': 0.863,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'hyper-realism',
#      'start': 119.092,
#      'end': 120.153,
#      'score': 0.867,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'is',
#      'start': 120.293,
#      'end': 120.373,
#      'score': 0.669,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'the',
#      'start': 120.433,
#      'end': 120.533,
#      'score': 0.815,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'best',
#      'start': 120.653,
#      'end': 120.954,
#      'score': 0.775,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'way',
#      'start': 121.014,
#      'end': 121.154,
#      'score': 0.949,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'to',
#      'start': 121.214,
#      'end': 121.274,
#      'score': 0.79,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'choose',
#      'start': 121.314,
#      'end': 121.574,
#      'score': 0.914,
#      'speaker': 'SPEAKER_00'},
#     {'word': "one's",
#      'start': 121.694,
#      'end': 121.895,
#      'score': 0.698,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'dreams',
#      'start': 121.955,
#      'end': 122.295,
#      'score': 0.832,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'and',
#      'start': 122.495,
#      'end': 122.595,
#      'score': 0.738,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'then',
#      'start': 122.655,
#      'end': 122.855,
#      'score': 0.838,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'achieve',
#      'start': 122.915,
#      'end': 123.276,
#      'score': 0.793,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'them.',
#      'start': 123.296,
#      'end': 123.376,
#      'score': 0.697,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 124.144,
#    'end': 133.268,
#    'text': ' Having big dreams plus embracing reality plus having lots of determination will bring you a successful life.',
#    'words': [{'word': 'Having',
#      'start': 124.144,
#      'end': 124.504,
#      'score': 0.864,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'big',
#      'start': 124.724,
#      'end': 125.004,
#      'score': 0.976,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'dreams',
#      'start': 125.064,
#      'end': 125.545,
#      'score': 0.762,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'plus',
#      'start': 126.045,
#      'end': 126.485,
#      'score': 0.825,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'embracing',
#      'start': 126.565,
#      'end': 127.105,
#      'score': 0.879,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'reality',
#      'start': 127.185,
#      'end': 127.786,
#      'score': 0.805,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'plus',
#      'start': 128.086,
#      'end': 128.466,
#      'score': 0.86,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'having',
#      'start': 128.686,
#      'end': 129.006,
#      'score': 0.871,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'lots',
#      'start': 129.366,
#      'end': 129.727,
#      'score': 0.893,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'of',
#      'start': 129.787,
#      'end': 129.867,
#      'score': 0.944,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'determination',
#      'start': 129.947,
#      'end': 130.747,
#      'score': 0.865,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'will',
#      'start': 130.987,
#      'end': 131.207,
#      'score': 0.812,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'bring',
#      'start': 131.247,
#      'end': 131.447,
#      'score': 0.74,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'you',
#      'start': 131.467,
#      'end': 131.607,
#      'score': 0.557,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'a',
#      'start': 131.647,
#      'end': 131.707,
#      'score': 0.346,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'successful',
#      'start': 131.748,
#      'end': 132.288,
#      'score': 0.847,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'life.',
#      'start': 132.348,
#      'end': 132.608,
#      'score': 0.754,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 133.268,
#    'end': 136.69,
#    'text': 'I believe this formula is true for everyone.',
#    'words': [{'word': 'I',
#      'start': 133.268,
#      'end': 133.368,
#      'score': 0.61,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'believe',
#      'start': 133.428,
#      'end': 133.848,
#      'score': 0.822,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'this',
#      'start': 133.949,
#      'end': 134.169,
#      'score': 0.749,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'formula',
#      'start': 134.309,
#      'end': 134.809,
#      'score': 0.869,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'is',
#      'start': 134.909,
#      'end': 134.969,
#      'score': 0.752,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'true',
#      'start': 135.049,
#      'end': 135.269,
#      'score': 0.676,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'for',
#      'start': 135.349,
#      'end': 135.509,
#      'score': 0.72,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'everyone.',
#      'start': 135.669,
#      'end': 136.13,
#      'score': 0.795,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 136.69,
#    'end': 139.411,
#    'text': 'But what does a successful life look like?',
#    'words': [{'word': 'But',
#      'start': 136.69,
#      'end': 136.83,
#      'score': 0.871,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'what',
#      'start': 136.93,
#      'end': 137.13,
#      'score': 0.658,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'does',
#      'start': 137.17,
#      'end': 137.37,
#      'score': 0.692,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'a',
#      'start': 137.45,
#      'end': 137.51,
#      'score': 0.365,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'successful',
#      'start': 137.57,
#      'end': 138.11,
#      'score': 0.898,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'life',
#      'start': 138.17,
#      'end': 138.371,
#      'score': 0.834,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'look',
#      'start': 138.431,
#      'end': 138.671,
#      'score': 0.768,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'like?',
#      'start': 138.711,
#      'end': 138.911,
#      'score': 0.904,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 139.411,
#    'end': 143.253,
#    'text': 'We each have to decide for ourselves what success is.',
#    'words': [{'word': 'We',
#      'start': 139.411,
#      'end': 139.571,
#      'score': 0.822,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'each',
#      'start': 139.691,
#      'end': 139.871,
#      'score': 0.648,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'have',
#      'start': 139.911,
#      'end': 140.091,
#      'score': 0.768,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'to',
#      'start': 140.131,
#      'end': 140.191,
#      'score': 0.978,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'decide',
#      'start': 140.251,
#      'end': 140.652,
#      'score': 0.9,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'for',
#      'start': 140.692,
#      'end': 140.812,
#      'score': 0.841,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'ourselves',
#      'start': 140.892,
#      'end': 141.432,
#      'score': 0.699,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'what',
#      'start': 141.512,
#      'end': 141.692,
#      'score': 0.714,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'success',
#      'start': 141.752,
#      'end': 142.232,
#      'score': 0.846,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'is.',
#      'start': 142.332,
#      'end': 142.452,
#      'score': 0.589,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 143.253,
#    'end': 149.536,
#    'text': "I don't care whether you want to be a master of the universe or to live under a palm tree or anything else.",
#    'words': [{'word': 'I',
#      'start': 143.253,
#      'end': 143.293,
#      'score': 0.68,
#      'speaker': 'SPEAKER_00'},
#     {'word': "don't",
#      'start': 143.313,
#      'end': 143.473,
#      'score': 0.841,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'care',
#      'start': 143.513,
#      'end': 143.713,
#      'score': 0.712,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'whether',
#      'start': 143.753,
#      'end': 143.993,
#      'score': 0.785,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'you',
#      'start': 144.033,
#      'end': 144.173,
#      'score': 0.963,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'want',
#      'start': 144.213,
#      'end': 144.353,
#      'score': 0.753,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'to',
#      'start': 144.393,
#      'end': 144.453,
#      'score': 0.792,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'be',
#      'start': 144.493,
#      'end': 144.613,
#      'score': 0.707,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'a',
#      'start': 144.653,
#      'end': 144.673,
#      'score': 0.998,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'master',
#      'start': 144.774,
#      'end': 145.234,
#      'score': 0.777,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'of',
#      'start': 145.294,
#      'end': 145.354,
#      'score': 0.75,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'the',
#      'start': 145.394,
#      'end': 145.494,
#      'score': 0.829,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'universe',
#      'start': 145.614,
#      'end': 146.134,
#      'score': 0.716,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'or',
#      'start': 146.394,
#      'end': 146.494,
#      'score': 0.573,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'to',
#      'start': 146.554,
#      'end': 146.654,
#      'score': 0.851,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'live',
#      'start': 146.754,
#      'end': 146.975,
#      'score': 0.694,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'under',
#      'start': 147.035,
#      'end': 147.255,
#      'score': 0.764,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'a',
#      'start': 147.295,
#      'end': 147.335,
#      'score': 0.501,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'palm',
#      'start': 147.415,
#      'end': 147.755,
#      'score': 0.994,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'tree',
#      'start': 147.815,
#      'end': 148.115,
#      'score': 0.722,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'or',
#      'start': 148.315,
#      'end': 148.415,
#      'score': 0.49,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'anything',
#      'start': 148.615,
#      'end': 148.995,
#      'score': 0.917,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'else.',
#      'start': 149.095,
#      'end': 149.256,
#      'score': 0.392,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 149.536,
#    'end': 150.136,
#    'text': "I really don't.",
#    'words': [{'word': 'I',
#      'start': 149.536,
#      'end': 149.596,
#      'score': 0.666,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'really',
#      'start': 149.636,
#      'end': 149.896,
#      'score': 0.71,
#      'speaker': 'SPEAKER_00'},
#     {'word': "don't.",
#      'start': 149.936,
#      'end': 150.136,
#      'score': 0.879,
#      'speaker': 'SPEAKER_00'}],
#    'speaker': 'SPEAKER_00'},
#   {'start': 151.778,
#    'end': 158.345,
#    'text': ' Each of us chooses goals based on our values and decides on the best path to achieve them.',
#    'words': [{'word': 'Each',
#      'start': 151.778,
#      'end': 151.938,
#      'score': 0.813,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'of',
#      'start': 151.998,
#      'end': 152.058,
#      'score': 0.75,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'us',
#      'start': 152.158,
#      'end': 152.259,
#      'score': 0.634,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'chooses',
#      'start': 152.359,
#      'end': 152.779,
#      'score': 0.668,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'goals',
#      'start': 152.859,
#      'end': 153.28,
#      'score': 0.81,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'based',
#      'start': 153.36,
#      'end': 153.64,
#      'score': 0.749,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'on',
#      'start': 153.72,
#      'end': 153.8,
#      'score': 0.745,
#      'speaker': 'SPEAKER_00'},
#     {'word': 'our',
#      'start': 153.88,
#      'end': 153.98,
# ...
#   {'word': 'like',
#    'start': 188.042,
#    'end': 188.222,
#    'score': 0.878,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'puzzles',
#    'start': 188.342,
#    'end': 188.842,
#    'score': 0.855,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'that',
#    'start': 189.142,
#    'end': 189.262,
#    'score': 0.894,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'would',
#    'start': 189.302,
#    'end': 189.482,
#    'score': 0.631,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'reward',
#    'start': 189.522,
#    'end': 190.043,
#    'score': 0.806,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'me',
#    'start': 190.083,
#    'end': 190.203,
#    'score': 0.778,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'if',
#    'start': 190.263,
#    'end': 190.343,
#    'score': 0.696,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'I',
#    'start': 190.423,
#    'end': 190.463,
#    'score': 1.0,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'could',
#    'start': 190.503,
#    'end': 190.643,
#    'score': 0.928,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'solve',
#    'start': 190.703,
#    'end': 191.003,
#    'score': 0.828,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'them.',
#    'start': 191.043,
#    'end': 191.163,
#    'score': 0.897,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'They',
#    'start': 191.783,
#    'end': 191.923,
#    'score': 0.902,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'would',
#    'start': 191.963,
#    'end': 192.123,
#    'score': 0.866,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'help',
#    'start': 192.163,
#    'end': 192.343,
#    'score': 0.762,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'me',
#    'start': 192.383,
#    'end': 192.483,
#    'score': 0.831,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'deal',
#    'start': 192.543,
#    'end': 192.724,
#    'score': 0.792,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'with',
#    'start': 192.764,
#    'end': 192.884,
#    'score': 0.818,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'the',
#    'start': 192.924,
#    'end': 193.024,
#    'score': 0.875,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'problem',
#    'start': 193.064,
#    'end': 193.484,
#    'score': 0.83,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'at',
#    'start': 193.524,
#    'end': 193.604,
#    'score': 0.704,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'hand.',
#    'start': 193.664,
#    'end': 193.944,
#    'score': 0.921,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'and',
#    'start': 194.44,
#    'end': 194.54,
#    'score': 0.887,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'they',
#    'start': 194.6,
#    'end': 194.74,
#    'score': 0.904,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'would',
#    'start': 194.78,
#    'end': 194.94,
#    'score': 0.707,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'give',
#    'start': 194.98,
#    'end': 195.161,
#    'score': 0.696,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'me',
#    'start': 195.201,
#    'end': 195.321,
#    'score': 0.83,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'principles',
#    'start': 195.441,
#    'end': 196.121,
#    'score': 0.812,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'for',
#    'start': 196.281,
#    'end': 196.421,
#    'score': 0.864,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'dealing',
#    'start': 196.481,
#    'end': 196.822,
#    'score': 0.778,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'with',
#    'start': 196.862,
#    'end': 196.982,
#    'score': 0.843,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'similar',
#    'start': 197.082,
#    'end': 197.522,
#    'score': 0.736,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'problems',
#    'start': 197.602,
#    'end': 198.103,
#    'score': 0.788,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'in',
#    'start': 198.163,
#    'end': 198.243,
#    'score': 0.826,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'the',
#    'start': 198.263,
#    'end': 198.323,
#    'score': 0.969,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'future.',
#    'start': 198.403,
#    'end': 198.823,
#    'score': 0.763,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'I',
#    'start': 199.844,
#    'end': 199.924,
#    'score': 0.505,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'learned',
#    'start': 200.024,
#    'end': 200.364,
#    'score': 0.609,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'to',
#    'start': 200.444,
#    'end': 200.544,
#    'score': 0.651,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'treat',
#    'start': 200.624,
#    'end': 200.884,
#    'score': 0.828,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'pain',
#    'start': 201.064,
#    'end': 201.485,
#    'score': 0.766,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'as',
#    'start': 201.645,
#    'end': 201.725,
#    'score': 0.76,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'a',
#    'start': 201.785,
#    'end': 201.805,
#    'score': 0.997,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'cue',
#    'start': 201.905,
#    'end': 202.285,
#    'score': 0.797,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'that',
#    'start': 202.545,
#    'end': 202.726,
#    'score': 0.726,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'a',
#    'start': 202.766,
#    'end': 202.806,
#    'score': 0.499,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'great',
#    'start': 202.906,
#    'end': 203.266,
#    'score': 0.724,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'learning',
#    'start': 203.386,
#    'end': 203.726,
#    'score': 0.765,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'opportunity',
#    'start': 203.826,
#    'end': 204.507,
#    'score': 0.792,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'is',
#    'start': 204.567,
#    'end': 204.667,
#    'score': 0.734,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'at',
#    'start': 204.727,
#    'end': 204.787,
#    'score': 0.746,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'hand,',
#    'start': 204.847,
#    'end': 205.207,
#    'score': 0.838,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'which',
#    'start': 205.688,
#    'end': 205.868,
#    'score': 0.708,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'led',
#    'start': 205.948,
#    'end': 206.148,
#    'score': 0.718,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'me',
#    'start': 206.188,
#    'end': 206.308,
#    'score': 0.62,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'to',
#    'start': 206.348,
#    'end': 206.428,
#    'score': 0.838,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'realize',
#    'start': 206.488,
#    'end': 207.049,
#    'score': 0.778,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'that',
#    'start': 207.589,
#    'end': 207.749,
#    'score': 0.851,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'pain',
#    'start': 207.929,
#    'end': 208.429,
#    'score': 0.842,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'plus',
#    'start': 208.79,
#    'end': 209.09,
#    'score': 0.815,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'reflection',
#    'start': 209.15,
#    'end': 209.93,
#    'score': 0.89,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'equals',
#    'start': 210.371,
#    'end': 210.791,
#    'score': 0.823,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'progress.',
#    'start': 210.891,
#    'end': 211.451,
#    'score': 0.92,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'Meditation',
#    'start': 212.592,
#    'end': 213.393,
#    'score': 0.903,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'has',
#    'start': 213.473,
#    'end': 213.613,
#    'score': 0.966,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'been',
#    'start': 213.653,
#    'end': 213.853,
#    'score': 0.77,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'invaluable',
#    'start': 213.913,
#    'end': 214.754,
#    'score': 0.832,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'in',
#    'start': 214.914,
#    'end': 214.994,
#    'score': 0.834,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'helping',
#    'start': 215.074,
#    'end': 215.374,
#    'score': 0.836,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'me',
#    'start': 215.414,
#    'end': 215.534,
#    'score': 0.834,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'see',
#    'start': 215.594,
#    'end': 215.774,
#    'score': 0.838,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'things',
#    'start': 215.834,
#    'end': 216.095,
#    'score': 0.756,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'that',
#    'start': 216.135,
#    'end': 216.315,
#    'score': 0.778,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'way.',
#    'start': 216.355,
#    'end': 216.495,
#    'score': 1.0,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'I',
#    'start': 217.478,
#    'end': 217.538,
#    'score': 0.666,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'found',
#    'start': 217.598,
#    'end': 217.818,
#    'score': 0.838,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'that',
#    'start': 217.858,
#    'end': 217.978,
#    'score': 0.893,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'when',
#    'start': 217.998,
#    'end': 218.138,
#    'score': 0.753,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'I',
#    'start': 218.198,
#    'end': 218.258,
#    'score': 0.666,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'calmed',
#    'start': 218.359,
#    'end': 218.759,
#    'score': 0.788,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'myself',
#    'start': 218.859,
#    'end': 219.279,
#    'score': 0.886,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'down',
#    'start': 219.339,
#    'end': 219.679,
#    'score': 0.864,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'and',
#    'start': 220.039,
#    'end': 220.119,
#    'score': 0.839,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'embraced',
#    'start': 220.179,
#    'end': 220.72,
#    'score': 0.779,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'my',
#    'start': 220.78,
#    'end': 220.96,
#    'score': 0.834,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'realities',
#    'start': 221.02,
#    'end': 221.64,
#    'score': 0.843,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'and',
#    'start': 222.14,
#    'end': 222.241,
#    'score': 0.672,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'dealt',
#    'start': 222.341,
#    'end': 222.621,
#    'score': 0.769,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'with',
#    'start': 222.681,
#    'end': 222.821,
#    'score': 0.925,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'them,',
#    'start': 222.881,
#    'end': 223.041,
#    'score': 0.916,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'the',
#    'start': 223.681,
#    'end': 223.821,
#    'score': 0.703,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'rewards',
#    'start': 223.881,
#    'end': 224.522,
#    'score': 0.763,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'brought',
#    'start': 224.622,
#    'end': 224.902,
#    'score': 0.733,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'me',
#    'start': 224.942,
#    'end': 225.082,
#    'score': 0.763,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'pleasure',
#    'start': 225.242,
#    'end': 225.782,
#    'score': 0.786,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'and',
#    'start': 226.203,
#    'end': 226.303,
#    'score': 0.674,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'the',
#    'start': 226.343,
#    'end': 226.423,
#    'score': 0.832,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'pain',
#    'start': 226.503,
#    'end': 226.863,
#    'score': 0.95,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'faded.',
#    'start': 226.983,
#    'end': 227.403,
#    'score': 0.835,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'Each',
#    'start': 228.004,
#    'end': 228.184,
#    'score': 0.774,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'of',
#    'start': 228.244,
#    'end': 228.324,
#    'score': 0.674,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'us',
#    'start': 228.444,
#    'end': 228.564,
#    'score': 0.633,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'has',
#    'start': 228.684,
#    'end': 228.904,
#    'score': 0.829,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'the',
#    'start': 228.944,
#    'end': 229.044,
#    'score': 0.666,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'unique',
#    'start': 229.124,
#    'end': 229.504,
#    'score': 0.746,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'capability',
#    'start': 229.544,
#    'end': 230.405,
#    'score': 0.87,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'to',
#    'start': 230.505,
#    'end': 230.625,
#    'score': 0.707,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'think',
#    'start': 230.745,
#    'end': 231.005,
#    'score': 0.818,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'logically,',
#    'start': 231.105,
#    'end': 231.785,
#    'score': 0.807,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'to',
#    'start': 231.846,
#    'end': 231.946,
#    'score': 0.972,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'reflect',
#    'start': 232.006,
#    'end': 232.446,
#    'score': 0.905,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'on',
#    'start': 232.526,
#    'end': 232.586,
#    'score': 0.82,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'ourselves',
#    'start': 232.646,
#    'end': 233.146,
#    'score': 0.841,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'and',
#    'start': 233.226,
#    'end': 233.326,
#    'score': 0.921,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'our',
#    'start': 233.406,
#    'end': 233.526,
#    'score': 0.811,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'circumstances.',
#    'start': 233.586,
#    'end': 234.447,
#    'score': 0.906,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'and',
#    'start': 234.807,
#    'end': 234.907,
#    'score': 0.668,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'to',
#    'start': 234.987,
#    'end': 235.127,
#    'score': 0.834,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'direct',
#    'start': 235.208,
#    'end': 235.708,
#    'score': 0.871,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'our',
#    'start': 235.868,
#    'end': 235.968,
#    'score': 0.903,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'own',
#    'start': 236.189,
#    'end': 236.369,
#    'score': 0.673,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'personal',
#    'start': 236.469,
#    'end': 236.969,
#    'score': 0.796,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'evolution.',
#    'start': 237.09,
#    'end': 237.67,
#    'score': 0.904,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'Doing',
#    'start': 237.97,
#    'end': 238.291,
#    'score': 0.871,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'this',
#    'start': 238.351,
#    'end': 238.511,
#    'score': 0.842,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'well',
#    'start': 238.691,
#    'end': 239.092,
#    'score': 0.836,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'is',
#    'start': 239.332,
#    'end': 239.432,
#    'score': 0.676,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'just',
#    'start': 239.592,
#    'end': 239.913,
#    'score': 0.806,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'a',
#    'start': 239.993,
#    'end': 240.033,
#    'score': 0.434,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'matter',
#    'start': 240.073,
#    'end': 240.373,
#    'score': 0.854,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'of',
#    'start': 240.413,
#    'end': 240.473,
#    'score': 0.75,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'following',
#    'start': 240.593,
#    'end': 241.094,
#    'score': 0.856,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'a',
#    'start': 241.114,
#    'end': 241.134,
#    'score': 0.0,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'simple',
#    'start': 241.474,
#    'end': 241.955,
#    'score': 0.862,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'five-step',
#    'start': 242.115,
#    'end': 242.836,
#    'score': 0.938,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'process.',
#    'start': 242.916,
#    'end': 243.456,
#    'score': 0.888,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'In',
#    'start': 243.777,
#    'end': 243.857,
#    'score': 0.879,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'episode',
#    'start': 244.017,
#    'end': 244.517,
#    'score': 0.852,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'three,',
#    'start': 244.577,
#    'end': 244.898,
#    'score': 0.883,
#    'speaker': 'SPEAKER_00'},
#   {'word': "we'll",
#    'start': 245.018,
#    'end': 245.278,
#    'score': 0.67,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'explore',
#    'start': 245.338,
#    'end': 245.879,
#    'score': 0.883,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'what',
#    'start': 245.959,
#    'end': 246.099,
#    'score': 0.757,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'that',
#    'start': 246.159,
#    'end': 246.359,
#    'score': 0.846,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'process',
#    'start': 246.439,
#    'end': 247.0,
#    'score': 0.699,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'is',
#    'start': 247.2,
#    'end': 247.36,
#    'score': 0.748,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'and',
#    'start': 247.861,
#    'end': 247.961,
#    'score': 0.68,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'how',
#    'start': 248.001,
#    'end': 248.121,
#    'score': 0.828,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'to',
#    'start': 248.141,
#    'end': 248.221,
#    'score': 0.756,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'use',
#    'start': 248.361,
#    'end': 248.502,
#    'score': 0.789,
#    'speaker': 'SPEAKER_00'},
#   {'word': 'it.',
#    'start': 248.562,
#    'end': 248.602,
#    'score': 0.996,
#    'speaker': 'SPEAKER_00'}]}
